# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

# %%
from bs4 import BeautifulSoup as bs

# %%
from urllib.request import urlopen

# %%
urls = ['https://wuzzuf.net/search/jobs/?a=navbl&filters%5Bcareer_level%5D%5B0%5D=Entry%20Level&filters%5Bcountry%5D%5B0%5D=Egypt&q=data%20analysis&',
      'https://wuzzuf.net/search/jobs/?a=navbl&filters%5Bcareer_level%5D%5B0%5D=Entry%20Level&filters%5Bcountry%5D%5B0%5D=Egypt&q=data%20analysis&start=1',
      'https://wuzzuf.net/search/jobs/?a=navbl&filters%5Bcareer_level%5D%5B0%5D=Entry%20Level&filters%5Bcountry%5D%5B0%5D=Egypt&q=data%20analysis&start=2',
      'https://wuzzuf.net/search/jobs/?a=navbl&filters%5Bcareer_level%5D%5B0%5D=Entry%20Level&filters%5Bcountry%5D%5B0%5D=Egypt&q=data%20analysis&start=3',
      'https://wuzzuf.net/search/jobs/?a=navbl&filters%5Bcareer_level%5D%5B0%5D=Entry%20Level&filters%5Bcountry%5D%5B0%5D=Egypt&q=data%20analysis&start=4']

# %%
f = open("datawazzuf-data_analysis5.csv", "w")
header = "job_title, company_name, job_type, area, experience\n"
f.write(header)

for url in urls:
    client = urlopen(url)
    html = client.read()
    client.close()
    soup = bs(html, "html.parser")
    containers = soup.find_all("div",{"class": "css-1gatmva e1v1l3u10"})
    for container in containers:
        jtitle = container.findAll("h2",{"class": "css-m604qf"})
        job_title = jtitle[0].text.strip()

        cname = container.findAll("a",{"class": "css-17s97q8"})
        company_name = cname[0].text.strip()

        jtype = container.findAll("div",{"class":"css-1lh32fc"})
        job_type = jtype[0].text.strip()
        
        aa = container.findAll("span",{"class": "css-5wys0k"})
        area = aa[0].text[:aa[0].text.index(',')].strip()
        
        exp = containers[0].findAll("div",{"class": "css-y4udm8"})
        experience = exp[0].text[exp[0].text.index('Exp')-15:exp[0].text.index('Exp')+3]
    
        f.write(job_title + ", " + company_name + ", " + job_type + "," + area + "," + experience + "\n")
f.close()

# %%
pd.read_csv('datawazzuf-data_analysis5.csv',encoding='cp1252',on_bad_lines='skip')
# Out:
#                                             job_title  \
# 0         Data Analysis Instructor (Excel - Power BI)
# 1   Financial Data Analyst - (French/Russian/Germa...
# 2                      English Financial Data Analyst
# 3                                        Data Analyst
# 4                                        Data Analyst
# ..                                                ...
# 69                                         Accountant
# 70                               Financial Accountant
# 71                                         Accountant
# 72                                Junior BI Developer
# 73                                  Junior Accountant
#
#                        company_name                                job_type  \
# 0                       EpsilonAI -   Full TimePart TimeFreelance / Project
# 1          World Vest Base (WVB ) -                               Full Time
# 2          World Vest Base (WVB ) -                               Full Time
# ...
